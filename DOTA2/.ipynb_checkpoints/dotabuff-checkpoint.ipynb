# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
def pprint(soup):
    if str(type(soup)) == "<class 'bs4.element.ResultSet'>":
        print(len(soup))
        for i in soup:
            # i=i.get('title')
            # print(i)
            print(i.prettify())
    elif str(type(soup)) in ["<class 'bs4.element.Tag'>","<class 'bs4.BeautifulSoup'>",]:
        print(soup.prettify())
    else:
        print([str(type(soup))])

    # print(soup)
pd.set_option('display.max_colwidth', None)
URL = 'https://www.dotabuff.com'
URL_trends = URL+'/heroes/trends'
page = requests.get(URL_trends, headers = {'User-agent': 'use_voice_communication_please research'})

soup = BeautifulSoup(page.content, "html.parser")
t = soup.prettify().split('\n')
for i in range(10):
    print(t[i])
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Heroes - Trends - DOTABUFF - Dota 2 Stats
#   </title>
#   <link href="/assets/application-76bf1668b74b95c4288fe40d1a58f54926c8384f2f74a3a0d24824204cc5dfcd.css" media="all" rel="stylesheet"/>
#   <link href="https://www.dotabuff.com/blog.rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <script src="/assets/application-6d204d61719e0a05a44c6ba4ba74219193f0181b57941d2b3cefdc04f7abd2ba.js">

# %%
# with open("./db_trends.html") as fp:
#     soup = BeautifulSoup(fp, 'html.parser')
# t = soup.prettify().split('\n')
# for i in range(10):
#     print(t[i])

# %%
table = soup.find('article')
tb = table.find('tbody')
df_trends = []
for i in tb.find_all('tr'):
    row = []
    t = i.find('a',attrs={'class':re.compile('link-type-hero')})
    row.append(t.get('href'))
    for j in i.find_all('td'):
        row.append(j.get('data-value'))
    df_trends.append(row)
    # pprint(i)
    # break
df_trends = pd.DataFrame(df_trends)

rename_cols = 'link,name,wr_prev,wr,d_wr,skip,pr_prev,pr,d_pr,skip'
rename_cols = rename_cols.split(',')
rename_cols = {i:j for i,j in enumerate(rename_cols)}
rename_cols
df_trends = df_trends.rename(columns=rename_cols)
filter = [i for i in rename_cols.values() if i != 'skip']
df_trends = df_trends[filter]
df_trends['link'] = URL+df_trends['link']



df_trends['id'] = df_trends['link'].str.split('/').str[6]
df_trends
# Out:
#                                                                link  \
# 0        https://www.dotabuff.com/heroes/trends/heroes/witch-doctor
# 1             https://www.dotabuff.com/heroes/trends/heroes/invoker
# 2           https://www.dotabuff.com/heroes/trends/heroes/sand-king
# 3    https://www.dotabuff.com/heroes/trends/heroes/phantom-assassin
# 4                https://www.dotabuff.com/heroes/trends/heroes/riki
# ..                                                              ...
# 119            https://www.dotabuff.com/heroes/trends/heroes/tinker
# 120        https://www.dotabuff.com/heroes/trends/heroes/arc-warden
# 121        https://www.dotabuff.com/heroes/trends/heroes/omniknight
# 122    https://www.dotabuff.com/heroes/trends/heroes/spirit-breaker
# 123             https://www.dotabuff.com/heroes/trends/heroes/meepo
#
#                  name  wr_prev       wr                 d_wr  pr_prev  \
# 0        Witch Doctor  50.6451  58.7045    8.059400000000004  17.7247
# 1             Invoker  48.4558  54.7933    6.337499999999999  13.3074
# 2           Sand King  52.3797  57.9785    5.598799999999997   6.1479
# 3    Phantom Assassin  47.3567   52.607    5.250300000000003   15.639
# 4                Riki  52.1508  57.2192    5.068400000000004   6.0059
# ..                ...      ...      ...                  ...      ...
# 119            Tinker  52.2448  48.5361  -3.7087000000000003   9.0646
# 120        Arc Warden  51.7331  47.7472   -3.985900000000001   3.7556
# 121        Omniknight  52.3166  48.1955   -4.121099999999998   5.4594
# 122    Spirit Breaker  51.1353  46.9862   -4.149100000000004  19.5813
# 123             Meepo  55.7973  47.8558   -7.941499999999998   5.2373
#
#           pr                 d_pr                id
# 0    21.6122    3.887500000000003      witch-doctor
# 1    18.8661               5.5587           invoker
# 2    10.4297   4.2818000000000005         sand-king
# 3     21.086    5.446999999999999  phantom-assassin
# 4    10.1955   4.1895999999999995              riki
# ..       ...                  ...               ...
# 119   8.0839  -0.9807000000000006            tinker
# 120   2.7754              -0.9802        arc-warden
# 121   3.6743  -1.7850999999999995        omniknight
# 122  15.9848   -3.596499999999999    spirit-breaker
# 123   3.3075  -1.9298000000000002             meepo
#
# [124 rows x 9 columns]

# %%
def i_counter(id):
    i_URL_counter = f'https://www.dotabuff.com/heroes/{id}/counters'
    print(i_URL_counter)
    i_page_counter = requests.get(i_URL_counter, headers = {'User-agent': 'use_voice_communication_please research'})
    i_soup_counter = BeautifulSoup(i_page_counter.content, "html.parser")
    for matchup  in i_soup_counter.find_all('section'):
        try:
            if matchup.find('header').text == 'Matchups':
                break
        except:
            print()
    table = matchup.find('article')
    tb = table.find('tbody') 
    # pprint(tb)
    df_counter = []
    for i in tb.find_all('tr'):
        row = []
        t = i.find('a',attrs={'class':re.compile('link-type-hero')})
        row.append(t.get('href'))
        for j in i.find_all('td'):
            row.append(j.get('data-value'))
        df_counter.append(row)
        # print(row)
        # pprint(t)
        # pprint(i)
        # break
    df_counter = pd.DataFrame(df_trends)
    return df_counter
    
    
for i,row in df_trends.iterrows():
    id = row["id"]
    i_counter(id)
    break

i_counter('witch-doctor')
# Out:
# https://www.dotabuff.com/heroes/witch-doctor/counters
#                                                                link  \
# 0        https://www.dotabuff.com/heroes/trends/heroes/witch-doctor
# 1             https://www.dotabuff.com/heroes/trends/heroes/invoker
# 2           https://www.dotabuff.com/heroes/trends/heroes/sand-king
# 3    https://www.dotabuff.com/heroes/trends/heroes/phantom-assassin
# 4                https://www.dotabuff.com/heroes/trends/heroes/riki
# ..                                                              ...
# 119            https://www.dotabuff.com/heroes/trends/heroes/tinker
# 120        https://www.dotabuff.com/heroes/trends/heroes/arc-warden
# 121        https://www.dotabuff.com/heroes/trends/heroes/omniknight
# 122    https://www.dotabuff.com/heroes/trends/heroes/spirit-breaker
# 123             https://www.dotabuff.com/heroes/trends/heroes/meepo
#
#                  name  wr_prev       wr                 d_wr  pr_prev  \
# 0        Witch Doctor  50.6451  58.7045    8.059400000000004  17.7247
# 1             Invoker  48.4558  54.7933    6.337499999999999  13.3074
# 2           Sand King  52.3797  57.9785    5.598799999999997   6.1479
# 3    Phantom Assassin  47.3567   52.607    5.250300000000003   15.639
# 4                Riki  52.1508  57.2192    5.068400000000004   6.0059
# ..                ...      ...      ...                  ...      ...
# 119            Tinker  52.2448  48.5361  -3.7087000000000003   9.0646
# 120        Arc Warden  51.7331  47.7472   -3.985900000000001   3.7556
# 121        Omniknight  52.3166  48.1955   -4.121099999999998   5.4594
# 122    Spirit Breaker  51.1353  46.9862   -4.149100000000004  19.5813
# 123             Meepo  55.7973  47.8558   -7.941499999999998   5.2373
#
#           pr                 d_pr                id
# 0    21.6122    3.887500000000003      witch-doctor
# 1    18.8661               5.5587           invoker
# 2    10.4297   4.2818000000000005         sand-king
# 3     21.086    5.446999999999999  phantom-assassin
# 4    10.1955   4.1895999999999995              riki
# ..       ...                  ...               ...
# 119   8.0839  -0.9807000000000006            tinker
# 120   2.7754              -0.9802        arc-warden
# 121   3.6743  -1.7850999999999995        omniknight
# 122  15.9848   -3.596499999999999    spirit-breaker
# 123   3.3075  -1.9298000000000002             meepo
#
# [124 rows x 9 columns]

# %%
df_trends.sort_values(by='wr',ascending=False)
# Out:
#                      link          name  wr_prev       wr  \
# 0    /heroes/witch-doctor  Witch Doctor  50.6451  58.7045
# 2       /heroes/sand-king     Sand King  52.3797  57.9785
# 4            /heroes/riki          Riki  52.1508  57.2192
# 10        /heroes/warlock       Warlock  52.5818  56.0115
# 1         /heroes/invoker       Invoker  48.4558  54.7933
# ..                    ...           ...      ...      ...
# 60    /heroes/enchantress   Enchantress  44.8943  44.4531
# 77      /heroes/morphling     Morphling  44.6939  43.5779
# 110     /heroes/timbersaw     Timbersaw  46.3784  43.5571
# 62       /heroes/batrider      Batrider  43.2432  42.6783
# 92    /heroes/broodmother   Broodmother  43.4557  41.6091
#
#                      d_wr  pr_prev       pr                 d_pr
# 0       8.059400000000004  17.7247  21.6122    3.887500000000003
# 2       5.598799999999997   6.1479  10.4297   4.2818000000000005
# 4       5.068400000000004   6.0059  10.1955   4.1895999999999995
# 10      3.429699999999997   5.1469   8.6907               3.5438
# 1       6.337499999999999  13.3074  18.8661               5.5587
# ..                    ...      ...      ...                  ...
# 60   -0.44120000000000203   4.5307   3.2303  -1.3004000000000002
# 77    -1.1159999999999997   6.7414   4.9399  -1.8014999999999999
# 110    -2.821300000000001   7.9082   5.4125  -2.4957000000000003
# 62    -0.5649000000000015   2.0897   1.3411  -0.7486000000000002
# 92    -1.8466000000000022   2.3611   1.0952              -1.2659
#
# [124 rows x 8 columns]

# %%
# !ls
# Out:
# 1.jpeg	3.jpeg	5.jpeg	7.jpeg		 db_trends.html
# 2.jpeg	4.jpeg	6.jpeg	db_trends_files  dotabuff.ipynb
